# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data exploration

# %%
# Importing the csv
tree_census = pd.read_csv('2015_NYC_Street_Tree_Census.csv')

# %%
# Checking how the file looks
tree_census.head(10)

# %%
# Checking the columns
tree_census.columns

# %%
# Keeping the columns that I'm going to work on
tree_census_subset = tree_census[['tree_id', 'tree_dbh', 'stump_diam', 'curb_loc', 'status', 'health', 'spc_latin', 'steward', 'sidewalk', 'problems', 'root_stone', 'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other', 'brch_light', 'brch_shoe', 'brch_other']]

# %%
tree_census_subset

# %%
# Checking the count of null values
tree_census_subset.isna().sum()

# %%
# Checking all the rows where 'health' is NaN
tree_census_subset[ tree_census_subset['health'].isna() ]
# Remove NaN's in data cleaning

# %%
# To get the general feel of the dataset
tree_census_subset.describe()

# %%
# Checking for datatypes
tree_census_subset.dtypes
# tree_id should be categorical not int

# %%
# Histogram
tree_census_subset.hist(bins=50, figsize=(20,10))
# Out:
# array([[<AxesSubplot: title={'center': 'tree_id'}>,
#         <AxesSubplot: title={'center': 'tree_dbh'}>],
#        [<AxesSubplot: title={'center': 'stump_diam'}>, <AxesSubplot: >]],
#       dtype=object)

# %%
# Outliers check
